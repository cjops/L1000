# %%
import numpy as np
import pandas as pd
from cmapPy.pandasGEXpress.parse import parse
import cmapPy.pandasGEXpress.write_gct as wg
import cmapPy.pandasGEXpress.write_gctx as wgx

# let's try GSE92742

gctx_file =      "GSE92742_Broad_LINCS_Level5_COMPZ.MODZ_n473647x12328.gctx" # 20 gigs 😳
sig_info_file =  "GSE92742_Broad_LINCS_sig_info.txt"
gene_info_file = "GSE92742_Broad_LINCS_gene_info.txt"
pert_info_file = "GSE92742_Broad_LINCS_pert_info.txt"
cell_info_file = "GSE92742_Broad_LINCS_cell_info.txt"

# GSE92743 is RNA-seq data used to verify accuracy of L1000, no perturbagens involved, so not very helpful

# %%
# get metadata

# columns
sig_info = pd.read_csv(
    sig_info_file,
    sep="\t"
)
sig_info.set_index("sig_id", inplace=True)

# rows
gene_info = pd.read_csv(
    gene_info_file,
    sep="\t",
    dtype={'pr_gene_id': 'str'}
)
gene_info.set_index("pr_gene_id", inplace=True)
# Out:
# /home/jops/miniconda3/envs/my_cmapPy_env/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2714: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# get perturbagen metadata
pert_info = pd.read_csv(
    pert_info_file,
    sep="\t",
    na_values=["-666", -666],
    index_col="pert_id"
)
pert_info['pubchem_cid'] = pd.to_numeric(pert_info['pubchem_cid'], errors='coerce').fillna('0').astype('Int64')

# %%
# perturbagens that NPC cells were exposed to, for example 
NPC_perts = sig_info["pert_id"][sig_info["cell_id"] == "NPC"].unique()
pert_info.loc[NPC_perts]['pert_iname'].values

# perturbagen exposure times
NPC_times = sig_info["pert_itime"][sig_info["cell_id"] == "NPC"].unique()
NPC_times
# Out:
# array(['96 h', '24 h', '6 h'], dtype=object)

# %%
# get cell line metadata
cell_info = pd.read_csv(
    cell_info_file,
    sep="\t",
    na_values=["-666", -666],
    index_col="cell_id"
)

# %%
# how many cell lines are described in metadata?
len(cell_info)
# Out:
# 98

# %%
# how many cell lines actually used in signatures?
cell_lines_used = sig_info['cell_id'].unique()
len(cell_lines_used)
# Out:
# 76

# %%
# all cell lines we have data for
cell_info.loc[cell_lines_used]
# Out:
#                cell_type base_cell_id precursor_cell_id  \
# cell_id
# CD34             primary         CD34               NaN
# HL60           cell line         HL60               NaN
# PC3            cell line          PC3               NaN
# U937           cell line         U937               NaN
# MCF7           cell line         MCF7               NaN
# A375           cell line         A375               NaN
# HEK293T        cell line      HEK293T               NaN
# A549           cell line         A549               NaN
# ASC              primary          ASC               NaN
# HA1E           cell line         HA1E               NaN
# HCC515         cell line       HCC515               NaN
# HEKTE          cell line        HEKTE               NaN
# HEPG2          cell line        HEPG2               NaN
# HT29           cell line         HT29               NaN
# NCIH716        cell line      NCIH716               NaN
# NPC       differentiated          NPC               NaN
# SHSY5Y         cell line       SHSY5Y               NaN
# SKL              primary          SKL               NaN
# SW480          cell line        SW480               NaN
# VCAP           cell line         VCAP               NaN
# BT20           cell line         BT20               NaN
# FIBRNPC             iPSC      FIBRNPC               NaN
# HS578T         cell line       HS578T               NaN
# MCF10A         cell line       MCF10A               NaN
# MCH58          cell line        MCH58               NaN
# MDAMB231       cell line     MDAMB231               NaN
# NEU       differentiated          NEU               NaN
# NKDBA          cell line        NKDBA               NaN
# NOMO1          cell line        NOMO1               NaN
# PHH              primary          PHH               NaN
# ...                  ...          ...               ...
# JHUEM2         cell line       JHUEM2               NaN
# LOVO           cell line         LOVO               NaN
# MDST8          cell line        MDST8               NaN
# NCIH1694       cell line     NCIH1694               NaN
# NCIH1836       cell line     NCIH1836               NaN
# NCIH2073       cell line     NCIH2073               NaN
# NCIH508        cell line      NCIH508               NaN
# NCIH596        cell line      NCIH596               NaN
# OV7            cell line          OV7               NaN
# PL21           cell line         PL21               NaN
# RKO            cell line          RKO               NaN
# RMGI           cell line         RMGI               NaN
# RMUGS          cell line        RMUGS               NaN
# SKLU1          cell line        SKLU1               NaN
# SKMEL1         cell line       SKMEL1               NaN
# SKMEL28        cell line      SKMEL28               NaN
# SNGM           cell line         SNGM               NaN
# SNU1040        cell line      SNU1040               NaN
# SNUC4                NaN          NaN               NaN
# SNUC5          cell line        SNUC5               NaN
# SW620          cell line        SW620               NaN
# SW948          cell line        SW948               NaN
# T3M10          cell line        T3M10               NaN
# TYKNU          cell line        TYKNU               NaN
# WSUDLCL2       cell line     WSUDLCL2               NaN
# HUH7           cell line         HUH7               NaN
# HS27A          cell line        HS27A               NaN
# JURKAT         cell line       JURKAT               NaN
# U266           cell line         U266               NaN
# U2OS           cell line         U2OS               NaN
#
#                                                modification sample_type  \
# cell_id
# CD34                                                    NaN      normal
# HL60                                                    NaN       tumor
# PC3                                                     NaN       tumor
# U937                                                    NaN       tumor
# MCF7                                                    NaN       tumor
# A375                                                    NaN       tumor
# HEK293T                                 immortalized normal      normal
# A549                                                    NaN       tumor
# ASC                                                     NaN     primary
# HA1E                                    immortalized normal      normal
# HCC515                                                  NaN      normal
# HEKTE                                   immortalized normal      normal
# HEPG2                                                   NaN       tumor
# HT29                                                    NaN       tumor
# NCIH716                                                 NaN       tumor
# NPC       differentiated from iPSC, but not terminally d...     primary
# SHSY5Y                                                  NaN       tumor
# SKL                                                     NaN     primary
# SW480                                                   NaN       tumor
# VCAP                                                    NaN       tumor
# BT20                                                    NaN       tumor
# FIBRNPC                                                 NaN      normal
# HS578T                                                  NaN       tumor
# MCF10A                                  immortalized normal      normal
# MCH58                                   immortalized normal      normal
# MDAMB231                                                NaN       tumor
# NEU                 terminally differentiated to be neurons      normal
# NKDBA     hTERT-immortalized normal kidney cells immunos...      normal
# NOMO1                                                   NaN       tumor
# PHH                                                     NaN     primary
# ...                                                     ...         ...
# JHUEM2                                                  NaN       tumor
# LOVO                                                    NaN       tumor
# MDST8                                                   NaN       tumor
# NCIH1694                                                NaN       tumor
# NCIH1836                                                NaN       tumor
# NCIH2073                                                NaN       tumor
# NCIH508                                                 NaN       tumor
# NCIH596                                                 NaN       tumor
# OV7                                                     NaN       tumor
# PL21                                                    NaN       tumor
# RKO                                                     NaN       tumor
# RMGI                                                    NaN       tumor
# RMUGS                                                   NaN       tumor
# SKLU1                                                   NaN       tumor
# SKMEL1                                                  NaN       tumor
# SKMEL28                                                 NaN       tumor
# SNGM                                                    NaN       tumor
# SNU1040                                                 NaN       tumor
# SNUC4                                                   NaN         NaN
# SNUC5                                                   NaN       tumor
# SW620                                                   NaN       tumor
# SW948                                                   NaN       tumor
# T3M10                                                   NaN       tumor
# TYKNU                                                   NaN       tumor
# WSUDLCL2                                                NaN       tumor
# HUH7                                                    NaN       tumor
# HS27A              bone marrow cells that were immortalized      normal
# JURKAT                                                  NaN       tumor
# U266                                                    NaN       tumor
# U2OS                                                    NaN       tumor
#
#                                 primary_site  \
# cell_id
# CD34                                    bone
# HL60      haematopoietic and lymphoid tissue
# PC3                                 prostate
# U937      haematopoietic and lymphoid tissue
# MCF7                                  breast
# A375                                    skin
# HEK293T                               kidney
# A549                                    lung
# ASC                                  adipose
# HA1E                                  kidney
# HCC515                                  lung
# HEKTE                                 kidney
# HEPG2                                  liver
# HT29                         large intestine
# NCIH716                      large intestine
# NPC                   central nervous system
# SHSY5Y                     autonomic ganglia
# SKL                                   muscle
# SW480                        large intestine
# VCAP                                prostate
# BT20                                  breast
# FIBRNPC                                 skin
# HS578T                                breast
# MCF10A                                breast
# MCH58                                   skin
# MDAMB231                              breast
# NEU                                      NaN
# NKDBA                                 kidney
# NOMO1     haematopoietic and lymphoid tissue
# PHH                                    liver
# ...                                      ...
# JHUEM2                           endometrium
# LOVO                         large intestine
# MDST8                        large intestine
# NCIH1694                                lung
# NCIH1836                                lung
# NCIH2073                                lung
# NCIH508                      large intestine
# NCIH596                                 lung
# OV7                                    ovary
# PL21      haematopoietic and lymphoid tissue
# RKO                          large intestine
# RMGI                                   ovary
# RMUGS                                  ovary
# SKLU1                                   lung
# SKMEL1                                  skin
# SKMEL28                                 skin
# SNGM                             endometrium
# SNU1040                      large intestine
# SNUC4                                    NaN
# SNUC5                        large intestine
# SW620                        large intestine
# SW948                        large intestine
# T3M10                                   lung
# TYKNU                                  ovary
# WSUDLCL2  haematopoietic and lymphoid tissue
# HUH7                                   liver
# HS27A                                   bone
# JURKAT    haematopoietic and lymphoid tissue
# U266                                   blood
# U2OS                                    bone
#
#                                                     subtype  \
# cell_id
# CD34                                            bone marrow
# HL60      acute myelogenous leukemia (AML)| M3 (promyelo...
# PC3                                          adenocarcinoma
# U937           lymphoma| B-cell| non-hodgkin's| histiocytic
# MCF7                                         adenocarcinoma
# A375                                     malignant melanoma
# HEK293T                                    embryonal kidney
# A549                  non small cell lung cancer| carcinoma
# ASC                     normal primary adipocyte stem cells
# HA1E                                          normal kidney
# HCC515                                            carcinoma
# HEKTE                                            epithelial
# HEPG2                              hepatocellular carcinoma
# HT29                              colorectal adenocarcinoma
# NCIH716                           colorectal adenocarcinoma
# NPC                    normal stem fibroblast-derived iPScs
# SHSY5Y                                        neuroblastoma
# SKL                    normal primary skeletal muscle cells
# SW480                             colorectal adenocarcinoma
# VCAP                                              carcinoma
# BT20                                              carcinoma
# FIBRNPC                                                 NaN
# HS578T                                            carcinoma
# MCF10A                                           epithelial
# MCH58                                       skin fibroblast
# MDAMB231                                     adenocarcinoma
# NEU                                                     NaN
# NKDBA                                     kidney epithelial
# NOMO1                          acute myeloid leukemia (AML)
# PHH                                    normal primary liver
# ...                                                     ...
# JHUEM2    endometrial adenocarcinoma| endometrioid carci...
# LOVO                              colorectal adenocarcinoma
# MDST8                                  colorectal carcinoma
# NCIH1694                  small cell lung cancer| carcinoma
# NCIH1836                  small cell lung cancer| carcinoma
# NCIH2073         non small cell lung cancer| adenocarcinoma
# NCIH508                           colorectal adenocarcinoma
# NCIH596   non small cell lung cancer| adenosquamous carc...
# OV7                                               carcinoma
# PL21              acute myelogenous leukemia| promyelocytic
# RKO                                    colorectal carcinoma
# RMGI                                  carcinoma| clear cell
# RMUGS                                             carcinoma
# SKLU1            non small cell lung cancer| adenocarcinoma
# SKMEL1                                   malignant melanoma
# SKMEL28                                  malignant melanoma
# SNGM                             endometrial adenocarcinoma
# SNU1040                                colorectal carcinoma
# SNUC4                                                   NaN
# SNUC5                             colorectal adenocarcinoma
# SW620                             colorectal adenocarcinoma
# SW948                             colorectal adenocarcinoma
# T3M10      non small cell lung cancer| large cell carcinoma
# TYKNU                           carcinoma| undifferentiated
# WSUDLCL2  lymphoma| B-cell| non-hodgkin's| diffuse large...
# HUH7                               hepatocellular carcinoma
# HS27A                                           bone marrow
# JURKAT           acute lymphoblastic leukemia (ALL)| T-cell
# U266                      myeloman, haematopoietic,lymphoid
# U2OS                                           osteosarcoma
#
#          original_growth_pattern provider_catalog_id original_source_vendor  \
# cell_id
# CD34                  suspension                 NaN                    NaN
# HL60                  suspension             CCL-240                   ATCC
# PC3                          mix            CRL-1435                   ATCC
# U937                  suspension          CRL-1593.2                   ATCC
# MCF7                    adherent              HTB-22                   ATCC
# A375                    adherent            CRL-1619                   ATCC
# HEK293T                 adherent                 NaN                    NaN
# A549                    adherent             CCL-185                   ATCC
# ASC                     adherent                 NaN                    NaN
# HA1E                    adherent                 NaN                    NaN
# HCC515                  adherent                 NaN                    NaN
# HEKTE                        NaN                 NaN                    NaN
# HEPG2                   adherent             HB-8065                   ATCC
# HT29                    adherent              HTB-38                   ATCC
# NCIH716               suspension             CCL-251                   ATCC
# NPC                     adherent                 NaN                    NaN
# SHSY5Y                       mix            CRL-2266                   ATCC
# SKL                     adherent             CC-2561                  LONZA
# SW480                   adherent             CCL-228                   ATCC
# VCAP                    adherent                 NaN                   ATCC
# BT20                    adherent              HTB-19                   ATCC
# FIBRNPC                 adherent                 NaN                    NaN
# HS578T                  adherent             HTB-126                   ATCC
# MCF10A                  adherent           CRL-10317                   ATCC
# MCH58                        NaN                 NaN                    NaN
# MDAMB231                adherent              HTB-26                   ATCC
# NEU                     adherent                 NaN                    NaN
# NKDBA                        NaN                 NaN                    NaN
# NOMO1                 suspension                 NaN                  HSRRB
# PHH                          NaN                 NaN            CellzDirect
# ...                          ...                 ...                    ...
# JHUEM2                  adherent                 NaN                  RIKEN
# LOVO                    adherent             CCL-229                   ATCC
# MDST8                   adherent                 NaN                  ECACC
# NCIH1694              suspension            CRL-5888                   ATCC
# NCIH1836              suspension            CRL-5898                   ATCC
# NCIH2073                adherent            CRL-5918                   ATCC
# NCIH508                      mix             CCL-253                   ATCC
# NCIH596                 adherent             HTB-178                   ATCC
# OV7                     adherent                 NaN                  ECACC
# PL21                  suspension                 NaN                   DSMZ
# RKO                     adherent                 NaN                   ATCC
# RMGI                    adherent                 NaN                  HSRRB
# RMUGS                   adherent                 NaN                  HSRRB
# SKLU1                   adherent              HTB-57                   ATCC
# SKMEL1                suspension              HTB-67                   ATCC
# SKMEL28                 adherent              HTB-72                   ATCC
# SNGM                    adherent                 NaN                  HSRRB
# SNU1040                      mix                 NaN                   KCLB
# SNUC4                        NaN                 NaN                    NaN
# SNUC5                   adherent                 NaN                   KCLB
# SW620                   adherent             CCL-227                   ATCC
# SW948                   adherent             CCL-237                   ATCC
# T3M10                   adherent                 NaN                  RIKEN
# TYKNU                   adherent                 NaN                  HSRRB
# WSUDLCL2              suspension                 NaN                   DSMZ
# HUH7                    adherent                 NaN                  HSRRB
# HS27A                   adherent                 NaN                    NaN
# JURKAT                suspension                 NaN                   DSMZ
# U266                         mix                ACC9                   DSMZ
# U2OS                    adherent              HTB-96                   ATCC
#
#           donor_age donor_sex donor_ethnicity
# cell_id
# CD34            NaN       NaN             NaN
# HL60           36.0         F       Caucasian
# PC3            62.0         M       Caucasian
# U937           37.0         M       Caucasian
# MCF7           69.0         F       Caucasian
# A375           54.0         F             NaN
# HEK293T         NaN       NaN             NaN
# A549           58.0         M       Caucasian
# ASC             NaN       NaN             NaN
# HA1E            NaN       NaN             NaN
# HCC515          NaN       NaN             NaN
# HEKTE           NaN       NaN             NaN
# HEPG2          15.0         M       Caucasian
# HT29           44.0         F       Caucasian
# NCIH716        33.0         M       Caucasian
# NPC             NaN       NaN             NaN
# SHSY5Y          NaN         F             NaN
# SKL             NaN       NaN             NaN
# SW480          50.0         M       Caucasian
# VCAP            NaN         M             NaN
# BT20           74.0         F       Caucasian
# FIBRNPC         NaN       NaN             NaN
# HS578T         74.0         F       Caucasian
# MCF10A          NaN       NaN             NaN
# MCH58           NaN       NaN             NaN
# MDAMB231       51.0         F       Caucasian
# NEU             NaN       NaN             NaN
# NKDBA           NaN         M             NaN
# NOMO1           NaN         F             NaN
# PHH             NaN       NaN             NaN
# ...             ...       ...             ...
# JHUEM2          NaN         F             NaN
# LOVO           56.0         M             NaN
# MDST8           NaN       NaN             NaN
# NCIH1694       61.0         M       Caucasian
# NCIH1836       52.0         M       Caucasian
# NCIH2073       47.0         F       Caucasian
# NCIH508        55.0         M       Caucasian
# NCIH596        73.0         M       Caucasian
# OV7             NaN         F             NaN
# PL21            NaN         M             NaN
# RKO             NaN       NaN             NaN
# RMGI            NaN         F             NaN
# RMUGS           NaN         F             NaN
# SKLU1          60.0         F       Caucasian
# SKMEL1         29.0         M       Caucasian
# SKMEL28        51.0         M             NaN
# SNGM            NaN         F             NaN
# SNU1040         NaN         M             NaN
# SNUC4           NaN       NaN             NaN
# SNUC5           NaN         F             NaN
# SW620          51.0         M       Caucasian
# SW948          81.0         F       Caucasian
# T3M10           NaN         M             NaN
# TYKNU           NaN         F             NaN
# WSUDLCL2        NaN         M             NaN
# HUH7            NaN         M             NaN
# HS27A           NaN       NaN             NaN
# JURKAT          NaN         M             NaN
# U266            NaN       NaN             NaN
# U2OS           15.0         F       Caucasian
#
# [76 rows x 13 columns]

# %%
# perturbagens for just NPC and NEU

#pd.set_option('display.max_rows', None)
all_perts = {}
for cell in ["NPC", "NEU"]:
    for pert in set(sig_info["pert_id"][sig_info["cell_id"] == cell]):
        if pert in all_perts:
            all_perts[pert].append(cell)
        else:
            all_perts[pert] = [cell]
pert_info2 = pert_info.loc[all_perts.keys()].sort_values('pert_iname')
pert_info2['cell_lines'] = pd.Series(all_perts)
pert_info2
#pert_info2.to_csv('all_perts_GSE92742.csv')
# Out:
#                                                      pert_iname pert_type  \
# pert_id
# BRD-A76934284            (+)-3-(1-propyl-piperidin-3-yl)-phenol    trt_cp
# BRD-A18795974  (+/-)-7-hydroxy-2-(N,N-di-n-propylamino)tetralin    trt_cp
# BRD-K06817181                  1,2,3,4,5,6-hexabromocyclohexane    trt_cp
# BRD-K18436203                    1,2,3,4-tetrahydroisoquinoline    trt_cp
# BRD-K74430258                               1,2-dichlorobenzene    trt_cp
# BRD-K02603382                              1-methylisoquinoline    trt_cp
# BRD-A80928489                                    1-monopalmitin    trt_cp
# BRD-K31491153                                 1-phenylbiguanide    trt_cp
# BRD-K70792160                                           10-DEBC    trt_cp
# BRD-K63784565                            10-hydroxycamptothecin    trt_cp
# BRD-K05396879                         15-delta-prostaglandin-j2    trt_cp
# BRD-K35128472                                     2-aminopurine    trt_cp
# BRD-A04831598                                   2-aminotetralin    trt_cp
# BRD-K37846922                             3,3'-diindolylmethane    trt_cp
# BRD-K32480606                              3,6-dimethoxyflavone    trt_cp
# BRD-A87125127                                          3-matida    trt_cp
# BRD-A62890442                                     3-methyl-GABA    trt_cp
# BRD-K97118047                   4,5,6,7-tetrabromobenzotriazole    trt_cp
# BRD-A80383043             4-carboxy-3-hydroxyphenylglycine-(RS)    trt_cp
# BRD-A15914070                               4-hydroxy-2-nonenal    trt_cp
# BRD-A96799240                            4-hydroxyretinoic-acid    trt_cp
# BRD-A00150179                               5-hydroxytryptophan    trt_cp
# BRD-A18497530                                  5-iodotubercidin    trt_cp
# BRD-A61866602                  5-methoxy-alpha-methyltryptamine    trt_cp
# BRD-K30197592                               5-methoxytryptamine    trt_cp
# BRD-A68318914                                 5-methylhydantoin    trt_cp
# BRD-K00656370                                   6-aminochrysene    trt_cp
# BRD-A65327625                                6-hydroxytropinone    trt_cp
# BRD-K08227907                                   6-nitrodopamine    trt_cp
# BRD-A64489120                             6-nitronorepinephrine    trt_cp
# ...                                                         ...       ...
# BRD-K46212057                                      voriconazole    trt_cp
# BRD-K81418486                                        vorinostat    trt_cp
# BRD-K25991148                                          warfarin    trt_cp
# BRD-A18579359                                       wiskostatin    trt_cp
# BRD-A52193669                                      withaferin-a    trt_cp
# BRD-A75409952                                        wortmannin    trt_cp
# BRD-A11678676                                        wortmannin    trt_cp
# BRD-K88358234                                        xaliproden    trt_cp
# BRD-K92446736   COc1ccc(CCN(C)CCCN2CCc3cc(OC)c(OC)cc3CC2=O)cc1OC        65637
# BRD-K87714311         OC[C@H]1O[C@H]([C@H](O)[C@@H]1O)n1cccnc1=O       100016
# BRD-K31553034  COc1nc(C)cnc1NS(=O)(=O)c1cccnc1-c1ccc(cc1)-c1n...      9910224
# BRD-K29582115       Clc1cc2NC(=O)Cc2cc1CCN1CCN(CC1)c1nsc2ccccc12        60854
# BRD-K08996725            C(CNc1nc2ccccc2s1)COc1cccc(CN2CCCCC2)c1     23640915
# BRD-K54314721          CN(C)CCc1c[nH]c2ccc(C[C@H]3COC(=O)N3)cc12        60857
# BRD-K48300629                           NS(=O)(=O)Cc1noc2ccccc12            0
# BRD-A28095882               CN1C2CCC1CC(C2)OC(c3ccccc3)c4ccccc4N         2143
# BRD-K70557564  O[C@@H](COc1cccc2ncccc12)CN1CCN(CC1)[C@@H]1c2c...      3036703
# BRD-K66353228                                 Nc1nc2cc(Cl)ccc2o1            0
# BRD-K28761384        OCCN1CCN(CC\C=C2\c3ccccc3Sc3ccc(Cl)cc23)CC1      5311507
#
#                cell_lines
# pert_id
# BRD-A76934284  [NPC, NEU]
# BRD-A18795974  [NPC, NEU]
# BRD-K06817181       [NPC]
# BRD-K18436203  [NPC, NEU]
# BRD-K74430258       [NPC]
# BRD-K02603382  [NPC, NEU]
# BRD-A80928489       [NPC]
# BRD-K31491153       [NPC]
# BRD-K70792160       [NEU]
# BRD-K63784565       [NPC]
# BRD-K05396879  [NPC, NEU]
# BRD-K35128472  [NPC, NEU]
# BRD-A04831598  [NPC, NEU]
# BRD-K37846922  [NPC, NEU]
# BRD-K32480606       [NPC]
# BRD-A87125127       [NPC]
# BRD-A62890442       [NPC]
# BRD-K97118047  [NPC, NEU]
# BRD-A80383043       [NPC]
# BRD-A15914070       [NPC]
# BRD-A96799240  [NPC, NEU]
# BRD-A00150179  [NPC, NEU]
# BRD-A18497530  [NPC, NEU]
# BRD-A61866602  [NPC, NEU]
# BRD-K30197592       [NPC]
# BRD-A68318914       [NPC]
# BRD-K00656370  [NPC, NEU]
# BRD-A65327625       [NPC]
# BRD-K08227907  [NPC, NEU]
# BRD-A64489120  [NPC, NEU]
# ...                   ...
# BRD-K46212057  [NPC, NEU]
# BRD-K81418486  [NPC, NEU]
# BRD-K25991148  [NPC, NEU]
# BRD-A18579359  [NPC, NEU]
# BRD-A52193669  [NPC, NEU]
# BRD-A75409952  [NPC, NEU]
# BRD-A11678676  [NPC, NEU]
# BRD-K88358234  [NPC, NEU]
# BRD-K77390737  [NPC, NEU]
# BRD-K12260308       [NPC]
# BRD-K21565985       [NPC]
# BRD-A51410489  [NPC, NEU]
# BRD-A87445400       [NPC]
# BRD-K57139258  [NPC, NEU]
# BRD-K60174629       [NPC]
# BRD-A65615053  [NPC, NEU]
# BRD-A26032986       [NPC]
# BRD-K12516989       [NPC]
# BRD-K37561857  [NPC, NEU]
# BRD-K92446736  [NPC, NEU]
# BRD-K87714311  [NPC, NEU]
# BRD-K31553034  [NPC, NEU]
# BRD-K29582115  [NPC, NEU]
# BRD-K08996725       [NPC]
# BRD-K54314721       [NPC]
# BRD-K48300629  [NPC, NEU]
# BRD-A28095882  [NPC, NEU]
# BRD-K70557564  [NPC, NEU]
# BRD-K66353228       [NPC]
# BRD-K28761384       [NPC]
#
# [8246 rows x 8 columns]

# %%
# many more perturbagens in this dataset

df.shape
# Out:
# (8246, 8)

# %%
len(sig_info["pert_id"].unique())
# Out:
# 51219

# %%
# do any perturbagens match similar molecules to ketamine?
# https://pubchem.ncbi.nlm.nih.gov/#query=CID3821%20structure&tab=similarity&similaritythreshold=80&fullsearch=true

# by pubchem cid:
pubchem_similar = pd.read_csv("pubchem_similar_80.csv", index_col="cid")
pert_info[pert_info['pubchem_cid'].isin(pubchem_similar.index)]
# Out:
#                 pert_iname pert_type  is_touchstone inchi_key_prefix  \
# pert_id
# BRD-A10355991  norketamine    trt_cp              1   BEQZHFIKTBVCAU
#
#                                  inchi_key         canonical_smiles  \
# pert_id
# BRD-A10355991  BEQZHFIKTBVCAU-UHFFFAOYSA-N  NC1(CCCCC1=O)c2ccccc2Cl
#
#                pubchem_cid
# pert_id
# BRD-A10355991       123767

# %%
# by name (also includes variant names for ketamine itself):
cmpdnames = set()
for cid, cmpdname, cmpdsynonym in zip(pubchem_similar.index, pubchem_similar['cmpdname'].values, pubchem_similar['cmpdsynonym'].values):
    cmpdnames.add(cmpdname)
    if type(cmpdsynonym) is not float:
        cmpdnames.update(cmpdsynonym.split('|'))
pert_info[pert_info['pert_iname'].str.lower().isin([c.lower() for c in cmpdnames])]
#len(cmpdnames)
# Out:
#                 pert_iname pert_type  is_touchstone inchi_key_prefix  \
# pert_id
# BRD-A05186015    bupropion    trt_cp              1   SNPPWIUOZRMYNY
# BRD-A10355991  norketamine    trt_cp              1   BEQZHFIKTBVCAU
#
#                                  inchi_key                canonical_smiles  \
# pert_id
# BRD-A05186015  SNPPWIUOZRMYNY-UHFFFAOYSA-N  CC(NC(C)(C)C)C(=O)c1cccc(Cl)c1
# BRD-A10355991  BEQZHFIKTBVCAU-UHFFFAOYSA-N         NC1(CCCCC1=O)c2ccccc2Cl
#
#                pubchem_cid
# pert_id
# BRD-A05186015            0
# BRD-A10355991       123767

# %%
# also check GSE70138 for similar molecules
# (bupropion is a hit but not for neuronal cell lines)
pert_info_file = "GSE70138_Broad_LINCS_pert_info_2017-03-06.txt"
pert_info_GSE70138 = pd.read_csv(
    pert_info_file,
    sep="\t",
    na_values=["-666", -666],
    index_col="pert_id"
)
pert_info_GSE70138[pert_info_GSE70138['pert_iname'].str.lower().isin([c.lower() for c in cmpdnames])]
# Out:
#                              canonical_smiles                    inchi_key  \
# pert_id
# BRD-A05186015  CC(NC(C)(C)C)C(=O)c1cccc(Cl)c1  SNPPWIUOZRMYNY-UHFFFAOYSA-N
#
#               pert_iname pert_type
# pert_id
# BRD-A05186015  bupropion    trt_cp

# %%
pert_info.loc[["BRD-A10355991", "BRD-A05186015"]]
# Out:
#                 pert_iname pert_type  is_touchstone inchi_key_prefix  \
# pert_id
# BRD-A10355991  norketamine    trt_cp              1   BEQZHFIKTBVCAU
# BRD-A05186015    bupropion    trt_cp              1   SNPPWIUOZRMYNY
#
#                                  inchi_key                canonical_smiles  \
# pert_id
# BRD-A10355991  BEQZHFIKTBVCAU-UHFFFAOYSA-N         NC1(CCCCC1=O)c2ccccc2Cl
# BRD-A05186015  SNPPWIUOZRMYNY-UHFFFAOYSA-N  CC(NC(C)(C)C)C(=O)c1cccc(Cl)c1
#
#                pubchem_cid
# pert_id
# BRD-A10355991       123767
# BRD-A05186015            0

# %%
bagot = pd.read_csv(
    "paper_bagot.csv"
)
bagot['Gene'].str.upper()
# Out:
# 0      ARRDC2
# 1       PLIN4
# 2      SLC2A1
# 3     TSC22D3
# 4       HIF3A
# 5      MAP3K6
# 6       TXNIP
# 7        SGK1
# 8      NFKBIA
# 9     PLEKHF1
# 10       RHOJ
# 11     CSRNP1
# 12       RGCC
# 13     MFSD2A
# 14    DCLRE1B
# 15      FGF11
# 16      ITGAD
# 17    SLC27A3
# 18      DDIT4
# 19    GADD45G
# 20     POLR3E
# 21    PPP1R3G
# 22    SULT1A1
# Name: Gene, dtype: object

# %%
norketamine = parse("norketamine.gct", make_multiindex=True)

# %%
criterion = norketamine.row_metadata_df['pr_gene_symbol'].isin(bagot['Gene'].str.upper())
df = pd.concat([norketamine.row_metadata_df[criterion], norketamine.data_df[criterion].iloc[:, 0]], axis=1)
df
# Out:
#       pr_gene_symbol                                      pr_gene_title  \
# rid
# 4792          NFKBIA  nuclear factor of kappa light polypeptide gene...
# 54541          DDIT4                  DNA damage inducible transcript 4
# 1831         TSC22D3                       TSC22 domain family member 3
# 11000        SLC27A3  solute carrier family 27 (fatty acid transport...
# 6446            SGK1            serum/glucocorticoid regulated kinase 1
# 6513          SLC2A1  solute carrier family 2 (facilitated glucose t...
# 10628          TXNIP                    thioredoxin interacting protein
# 6817         SULT1A1                sulfotransferase family 1A member 1
# 10912        GADD45G       growth arrest and DNA damage inducible gamma
# 55718         POLR3E  polymerase (RNA) III (DNA directed) polypeptid...
# 9064          MAP3K6   mitogen-activated protein kinase kinase kinase 6
# 64858        DCLRE1B                           DNA cross-link repair 1B
# 28984           RGCC                            regulator of cell cycle
# 64344          HIF3A          hypoxia inducible factor 3, alpha subunit
# 79156        PLEKHF1   pleckstrin homology and FYVE domain containing 1
#
#        pr_is_lm  pr_is_bing  CPC017_NPC_24H:BRD-A10355991-003-01-8:10
# rid
# 4792          1           1                                   -0.4730
# 54541         1           1                                   -0.4441
# 1831          1           1                                   -0.5525
# 11000         1           1                                   -0.0737
# 6446          0           1                                    0.1272
# 6513          0           1                                    0.0486
# 10628         0           1                                    0.4338
# 6817          0           1                                   -0.2094
# 10912         0           1                                   -0.2059
# 55718         0           1                                    0.0000
# 9064          0           1                                    0.6790
# 64858         0           1                                    0.9254
# 28984         0           1                                   -0.2476
# 64344         0           1                                    0.2174
# 79156         0           1                                    0.3387

# %%
norketamine.data_df.abs().mean()
# Out:
# cid
# CPC017_NPC_24H:BRD-A10355991-003-01-8:10    0.464671
# dtype: float32
